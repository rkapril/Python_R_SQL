# %%
from getpass import getpass

user = input("Enter username: ")
password = getpass("Enter password: ")
# Out:
# Enter username: root
# Enter password: ········

# %%
from getpass import getpass
from mysql.connector import connect, Error

try:
    with connect(
        host="localhost",
        user=user,
        password=password,
    ) as connection:
        print(connection)
except Error as e:
    print(e)
# Out:
# Authentication plugin 'caching_sha2_password' is not supported

# %%
import pyodbc
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'SQL Server Native Client 11.0',
#  'MySQL ODBC 8.0 ANSI Driver',
#  'MySQL ODBC 8.0 Unicode Driver',
#  'ODBC Driver 17 for SQL Server']

# %%
import pyodbc
password=password
conn = pyodbc.connect('DRIVER={MySQL ODBC 8.0 Unicode Driver};SERVER=localhost;DATABASE=test;UID=root;PWD='+ password)

cursor = conn.cursor()

# %%
import pandas as pd
# select command
query = ''' SELECT * FROM loan''';
data = pd.read_sql(query, conn)
data.head()
# Out:
#    Sr_num  SeriousDlqin2yrs  RevUtilizOfUnsecL   Age  NumOf30_59DaysPastDue  \
# 0     1.0               1.0           0.766127  45.0                    2.0
# 1     2.0               0.0           0.957151  40.0                    0.0
# 2     3.0               0.0           0.658180  38.0                    1.0
# 3     4.0               0.0           0.233810  30.0                    0.0
# 4     5.0               0.0           0.907239  49.0                    1.0
#
#    DebtRatio  MthlyIncome  NumOfOpenCreditLLoans  NumOf90DaysLate  \
# 0   0.802982       9120.0                   13.0              0.0
# 1   0.121876       2600.0                    4.0              0.0
# 2   0.085113       3042.0                    2.0              1.0
# 3   0.036050       3300.0                    5.0              0.0
# 4   0.024926      63588.0                    7.0              0.0
#
#    NumRealEstateLoansL  NumOf60_89DaysPastDue  NumOfDependents Obs_Type
# ...

# %%
cursor.execute('''
 DROP TABLE IF EXISTS PeopleInfo;
               ''')

conn.commit()

# %%
cursor.execute('''
 CREATE TABLE IF NOT EXISTS PeopleInfo (
        PersonId INTEGER PRIMARY KEY,
        FirstName TEXT NOT NULL,
        LastName  TEXT NOT NULL,
        Age INTEGER NULL
 
);
               ''')

conn.commit()

# %%
cursor.execute('''
                INSERT INTO PeopleInfo (PersonId, FirstName, LastName, Age)
                VALUES
                (1,'Bob','Smith', 55),
                (2, 'Jenny','Smith', 66)
                ''')
conn.commit()

# %%
cursor.execute('SELECT * FROM PeopleInfo')
for row in cursor:
    print(row)
# Out:
# (1, 'Bob', 'Smith', 55)
# (2, 'Jenny', 'Smith', 66)

# %%
query = ''' SELECT * FROM PeopleInfo''';
data = pd.read_sql(query, conn)
data.head()
# Out:
#    PersonId FirstName LastName  Age
# 0         1       Bob    Smith   55
# 1         2     Jenny    Smith   66

# %%
from getpass import getpass
import pyodbc
password=password
conn = pyodbc.connect('DRIVER={MySQL ODBC 8.0 Unicode Driver};SERVER=localhost;DATABASE=test;UID=root;PWD='+ password, autocommit=True)
cursor = conn.cursor()

# %%
cursor.execute('''
 DROP DATABASE IF EXISTS test;
               ''')

# %%
cursor.execute("create database test")

# %%
password=password
conn = pyodbc.connect('DRIVER={MySQL ODBC 8.0 Unicode Driver};SERVER=localhost;DATABASE=test;UID=root;PWD='+ password, autocommit=True)
cursor = conn.cursor()

# %%
cursor.execute('''
 DROP TABLE IF EXISTS PeopleInfo;
               ''')

# %%
cursor.execute('''
 CREATE TABLE IF NOT EXISTS PeopleInfo (
        PersonId INTEGER PRIMARY KEY,
        FirstName TEXT NOT NULL,
        LastName  TEXT NOT NULL,
        Age INTEGER NULL
 
);
               ''')

# %%
cursor.execute('''
                INSERT INTO PeopleInfo (PersonId, FirstName, LastName, Age)
                VALUES
                (1,'Bob','Smith', 55),
                (2, 'Jenny','Smith', 66)
                ''')

# %%
cursor.execute('SELECT * FROM PeopleInfo')
for row in cursor:
    print(row)
# Out:
# (1, 'Bob', 'Smith', 55)
# (2, 'Jenny', 'Smith', 66)

# %%
query = ''' SELECT * FROM PeopleInfo''';
data = pd.read_sql(query, conn)
data.head()
# Out:
#    PersonId FirstName LastName  Age
# 0         1       Bob    Smith   55
# 1         2     Jenny    Smith   66

# %%
import pandas as pd

# Create dataframe
data = pd.DataFrame({
    'book_id':[12345,12346,12347],
    'title':['Python Programming','Learn MySQL','Data Science Cookbook'],
    'price':[29,23,27]
})

data
# Out:
#    book_id                  title  price
# 0    12345     Python Programming     29
# 1    12346            Learn MySQL     23
# 2    12347  Data Science Cookbook     27

# %%
df = pd.read_csv("CW1_credit_data_cleaned.csv")

# %%
from sqlalchemy import create_engine

# %%
import pymysql
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=password,
                               db="test"))

# %%
df.to_sql('loan', con = engine, if_exists = 'replace', index = False)

# %%
connection = pymysql.connect(host='localhost',
                             user='root',
                             password=password,
                             db='test')

# %%
cursor = connection.cursor()

# %%
sqlQuery = "CREATE TABLE Employee(EmployeeID int, Ename varchar(32), DeptID int, Salary int, Dname varchar(32), Dlocation varchar(32))"

# %%
cursor.execute(sqlQuery)
# Out:
# 0

# %%
sql = "INSERT INTO `employee` (`EmployeeID`, `Ename`, `DeptID`, `Salary`, `Dname`, `Dlocation`) VALUES (%s, %s, %s, %s, %s, %s)"

# %%
cursor.execute(sql, (1008,'Kabir',2,5000,'IT','New Delhi'))
# Out:
# 1

# %%
sqlQuery = "show tables"

# %%
cursor.execute(sqlQuery)
# Out:
# 3

# %%
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('employee',)
# ('loan',)
# ('peopleinfo',)

# %%
sqlQuery = "DROP DATABASE IF EXISTS "+ "db"

# %%
cursor.execute(sqlQuery)
# Out:
# 0

# %%
sqlQuery = "CREATE DATABASE "+ "db"

# %%
cursor.execute(sqlQuery)
# Out:
# 1

# %%
sqlQuery = "SHOW DATABASES"

# %%
cursor.execute(sqlQuery)
# Out:
# 8

# %%
databaseList = cursor.fetchall()
 
for datatbase in databaseList:
    print(datatbase)
# Out:
# ('db',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('test',)
# ('world',)

# %%
sqlQuery = "DROP DATABASE IF EXISTS "+ "data"

# %%
cursor.execute(sqlQuery)
# Out:
# 0

# %%
sqlQuery = "SHOW DATABASES"

# %%
cursor.execute(sqlQuery)
# Out:
# 8

# %%
databaseList = cursor.fetchall()
 
for datatbase in databaseList:
    print(datatbase)
# Out:
# ('db',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('test',)
# ('world',)

# %%
sqlQuery = "DROP DATABASE IF EXISTS "+ "db"

# %%
cursor.execute(sqlQuery)
# Out:
# 0

# %%
sqlQuery = "SHOW DATABASES"

# %%
cursor.execute(sqlQuery)
# Out:
# 7

# %%
databaseList = cursor.fetchall()
 
for datatbase in databaseList:
    print(datatbase)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('test',)
# ('world',)

# %%
cursor.execute("SELECT * from employee")
# Out:
# 1

# %%
result = cursor.fetchall()

# %%
for i in result:
    print(i)
# Out:
# (1008, 'Kabir', 2, 5000, 'IT', 'New Delhi')

# %%
cursor.execute("SELECT * FROM employee WHERE DeptID=2")
# Out:
# 1

# %%
result = cursor.fetchall()

# %%
for i in result:
    print(i)
# Out:
# (1008, 'Kabir', 2, 5000, 'IT', 'New Delhi')
